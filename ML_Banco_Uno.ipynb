# %%
import sqlalchemy
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %% [markdown]
# <center> <h1> <font color='7FFF00'>Proyecto de Machine Learning para Banco Uno</font> </h1> </center>

# %% [markdown]
# <center> <img SRC="Banco.png" align=center/> </center>

# %% [markdown]
# <p> Ahora se creará la conexión a la base de datos de Banco Uno, esto establecerá un enlace entre el Jupyter Notebook y la base de datos para extaer la información necesaria para el desarrollo del proyecto:</p>

# %%
db_connection_str = 'mysql+pymysql://deepanalytics:Sqltask1234!@34.73.222.197/deepanalytics'
db_connection = create_engine(db_connection_str)

# %% [markdown]
# <p>Con la conexión finalizada, aplicaremos la sentencia SQL para extraer la data del respositorio de Banco Uno.</p>

# %%
df = pd.read_sql('SELECT * FROM credit', con=db_connection)

# %% [markdown]
# <p>Por úlitmo se procederá a guardar el Data Frame creado, en un archivo CSV y quedará almacenado en nuestra computadora:</p>

# %%
df.columns = df.iloc[0]
df = df[1:]

# %%
df.to_csv ( 'BancoUno.csv', header=True, index=False)

# %%
df
# Out:
# 0         ID LIMIT_BAL     SEX    EDUCATION MARRIAGE AGE PAY_0 PAY_2 PAY_3  \
# 1          1     20000  female   university        1  24     2     2    -1
# 2          2    120000  female   university        2  26    -1     2     0
# 3          3     90000  female   university        2  34     0     0     0
# 4          4     50000  female   university        1  37     0     0     0
# 5          5     50000    male   university        1  57    -1     0    -1
# ...      ...       ...     ...          ...      ...  ..   ...   ...   ...
# 30199  29996    220000    male  high school        1  39     0     0     0
# 30200  29997    150000    male  high school        2  43    -1    -1    -1
# 30201  29998     30000    male   university        2  37     4     3     2
# 30202  29999     80000    male  high school        1  41     1    -1     0
# 30203  30000     50000    male   university        1  46     0     0     0
#
# ...
